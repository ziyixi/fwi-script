# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
p_z=[1.7396918143692497e-05,1.687022830914653e-05,1.6402029284293936e-05,1.5997449762285577e-05,1.568114975206508e-05,1.5465821085891998e-05,1.535032366581252e-05,1.5300775625453874e-05,1.5343015391897286e-05]
depth=[-16,-12,-8,-4,0,4,8,12,16]

# %%
plt.figure(figsize=(14,6))
to_plot=p_z
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
p_r=[1.803737214887335e-05,1.735561834394938e-05,1.6769228623115693e-05,1.6239224292854483e-05,1.5794657151373975e-05,1.545811891496039e-05,1.5252826973099926e-05,1.5224498562022767e-05,1.5278477472507487e-05]

# %%
plt.figure(figsize=(14,6))
to_plot=p_r
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
s_z=[0.00010183383229775083,0.00010053684064645678,9.94475659051289e-05,9.982591168642075e-05,9.909467692551886e-05,9.853108468338617e-05,9.813306832808285e-05,9.793344789077536e-05,9.800065517552825e-05]

# %%
plt.figure(figsize=(14,6))
to_plot=s_z
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
s_r=[7.302369829759247e-05,7.230677926891381e-05,7.174123207248684e-05,7.135897823031314e-05,7.05306944262734e-05,7.123263482380992e-05,7.120071406859532e-05,7.163970963972696e-05,7.221496879767012e-05]

# %%
plt.figure(figsize=(14,6))
to_plot=s_r
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
s_t=[0.00010165326848395243,9.982888092866878e-05,9.827180181014829e-05,9.696734665231266e-05,9.595859209138747e-05,9.535442356677362e-05,9.484139791631333e-05,9.454747574523693e-05,9.465768584004601e-05]

# %%
plt.figure(figsize=(14,6))
to_plot=s_t
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surf_z=[6.1310728836366414e-06,6.246065615625789e-06,6.364350261963684e-06,6.228463193161747e-06,6.090422600706497e-06,5.942109743516939e-06,5.89445370551306e-06,5.727105840910541e-06,5.565150905283986e-06]

# %%
plt.figure(figsize=(14,6))
to_plot=surf_z
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# increase depth, amp down
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surf_r=[5.351574970491301e-06,5.1977541038965146e-06,5.1236937405528435e-06,4.9831771013892614e-06,4.89594760019303e-06,4.80047183754736e-06,4.691585871897843e-06,4.627531378398283e-06,4.551580451903363e-06]

# %%
plt.figure(figsize=(14,6))
to_plot=surf_r
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# increase depth, amp down
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surf_z_mt=[0.5966059150815215,0.640515444350875,0.6757979606979535,0.677946368189382,0.6689121930312087,0.6649012770858816,0.6682463562065574,0.6604307866811997,0.6537091180364056]

# %%
plt.figure(figsize=(14,6))
to_plot=surf_z_mt
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# increase depth, amp down, no adjust distance
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surf_r_mt=[0.5614567072741585,0.5517169427965697,0.5555045696978212,0.5463501910730042,0.5475143270013867,0.5495776667499456,0.542791804123593,0.5381930659813972,0.5376238129810519]

# %%
plt.figure(figsize=(14,6))
to_plot=surf_r_mt
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# increase depth, amp down, no adjust distance
# Out:
# Text(0, 0.5, 'misfit(m)')

# %% [markdown]
# # Use perturbation

# %%
p_z=[0.10258959503665883, 0.10042573323928544, 0.09867299720157492, 0.09699214726586812, 0.09550925689673208, 0.09432404723996095, 0.09343910858766959, 0.09272342199119046, 0.09237986726701734]
plt.figure(figsize=(14,6))
to_plot=p_z
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
p_r=[0.08743423083856822, 0.08504404592700697, 0.08429670574968352, 0.08273240136954854, 0.08071085518247476, 0.07901232681661477, 0.07858856121078533, 0.07792332043405267, 0.07796314000862026]
plt.figure(figsize=(14,6))
to_plot=p_r
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
s_z=[0.15593675775027704, 0.15435539251770308, 0.15269663149365276, 0.15149507630969455, 0.15074804477066872, 0.15009053158129412, 0.14969276691795763, 0.14967145983799543, 0.1500774675049772]
plt.figure(figsize=(14,6))
to_plot=s_z
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
s_r=[0.1514159836814518, 0.1496967738689147, 0.14871129350271725, 0.1475140119029581, 0.14393390316210655, 0.1435797897126668, 0.14313049443517684, 0.14333953058336857, 0.1440070473813608]
plt.figure(figsize=(14,6))
to_plot=s_r
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
s_t=[0.11889470176059913, 0.11704733793067874, 0.1154138561317403, 0.11351164321406564, 0.11216552834704255, 0.11115963644972547, 0.10984497493707429, 0.10935131491088335, 0.10898450639708768]
plt.figure(figsize=(14,6))
to_plot=s_t
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surf_z=[0.09537047700650535, 0.10406208562107756, 0.10983728510827566, 0.11054132142054174, 0.10969807329934594, 0.10966477365549898, 0.11059750474211211, 0.10919136943683877, 0.10702602490546713]
plt.figure(figsize=(14,6))
to_plot=surf_z
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surf_r=[0.10454210057011072, 0.10284211510434296, 0.10444402136800884, 0.10343582243588625, 0.10489872227917428, 0.10608902088403935, 0.1052607142392037, 0.10556831124717604, 0.10536762899391788]
plt.figure(figsize=(14,6))
to_plot=surf_r
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %% [markdown]
# # sum for perturbation

# %%
p_all=[0.09501191293761352, 0.09273488958314621, 0.09148485147562922, 0.08986227431770832, 0.08811005603960342, 0.08666818702828785, 0.08601383489922745, 0.08532337121262157, 0.08517150363781881]
plt.figure(figsize=(14,6))
to_plot=p_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
sv_all=[0.15367637071586443, 0.1520260831933089, 0.15070396249818502, 0.14950454410632633, 0.14734097396638762, 0.14683516064698046, 0.14641163067656723, 0.146505495210682, 0.147042257443169]
plt.figure(figsize=(14,6))
to_plot=sv_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
sh_all=[0.11889470176059913, 0.11704733793067874, 0.1154138561317403, 0.11351164321406564, 0.11216552834704255, 0.11115963644972547, 0.10984497493707429, 0.10935131491088335, 0.10898450639708768]
plt.figure(figsize=(14,6))
to_plot=sh_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
ray_all=[0.09995628878830803, 0.10345210036271027, 0.10714065323814226, 0.106988571928214, 0.10729839778926012, 0.10787689726976916, 0.1079291094906579, 0.1073798403420074, 0.10619682694969251]
plt.figure(figsize=(14,6))
to_plot=ray_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
theall=[0.11688481855059628, 0.11631510276746104, 0.11618583083592421, 0.11496675839157856, 0.11372873903557343, 0.11313497034869074, 0.11254988750088171, 0.11214000541904859, 0.111848773606942]
plt.figure(figsize=(14,6))
to_plot=theall
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %% [markdown]
# # sum for raw

# %%
p_all=[1.7396918143692497e-05, 1.687022830914653e-05, 1.6402029284293936e-05, 1.5997449762285577e-05, 1.568114975206508e-05, 1.5465821085891998e-05, 1.535032366581252e-05, 1.5300775625453874e-05, 1.5343015391897286e-05]
plt.figure(figsize=(14,6))
to_plot=p_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
sv_all=[8.742876529767166e-05, 8.64218099576853e-05, 8.559439898880787e-05, 8.559244495836695e-05, 8.481268567589613e-05, 8.488185975359804e-05, 8.466689119833909e-05, 8.478657876525116e-05, 8.510781198659918e-05]
plt.figure(figsize=(14,6))
to_plot=sv_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
sh_all=[0.00010165326848395243, 9.982888092866878e-05, 9.827180181014829e-05, 9.696734665231266e-05, 9.595859209138747e-05, 9.535442356677362e-05, 9.484139791631333e-05, 9.454747574523693e-05, 9.465768584004601e-05]

# %%
plt.figure(figsize=(14,6))
to_plot=sh_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
ray_all=[5.741323927063971e-06, 5.721909859761152e-06, 5.744022001258264e-06, 5.605820147275504e-06, 5.493185100449763e-06, 5.37129079053215e-06, 5.2930197887054516e-06, 5.177318609654411e-06, 5.058365678593674e-06]
plt.figure(figsize=(14,6))
to_plot=ray_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
theall=[5.3135125713742746e-05, 5.22713810181658e-05, 5.154896293847981e-05, 5.1070987196381286e-05, 5.050059157986322e-05, 5.02673860278325e-05, 5.0025721055703525e-05, 4.9943502553470206e-05, 5.003365248436031e-05]
plt.figure(figsize=(14,6))
to_plot=theall
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %% [markdown]
# # restrict azimuth

# %%
p_all=[2.5011107728519012e-05, 2.405027867889289e-05, 2.318997509639794e-05, 2.2439753475604795e-05, 2.184972327080255e-05, 2.148939203345861e-05, 2.1302372730044732e-05, 2.1332941413832155e-05, 2.146814491055574e-05]
plt.figure(figsize=(14,6))
to_plot=p_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
sv_all=[8.952377830576671e-05, 8.853601118043885e-05, 8.773375794257494e-05, 8.785022068702233e-05, 8.743744685092202e-05, 8.716168242665597e-05, 8.709355544850967e-05, 8.727945121499874e-05, 8.780389799462885e-05]
plt.figure(figsize=(14,6))
to_plot=sv_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
sh_all=[8.81634722899729e-05, 8.634899709996391e-05, 8.483268247790098e-05, 8.360962536172663e-05, 8.275651916447349e-05, 8.236628073274807e-05, 8.210031431633396e-05, 8.20817643914884e-05, 8.250663877477794e-05]
plt.figure(figsize=(14,6))
to_plot=sh_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
ray_all= [6.368415690861028e-06, 6.233714866486431e-06, 6.2986840485506715e-06, 6.148269015687271e-06, 6.03264508615189e-06, 5.900502896367628e-06, 5.83024997383602e-06, 5.716999203459738e-06, 5.5799472996959065e-06]
plt.figure(figsize=(14,6))
to_plot=ray_all
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
theall= [5.226669350377991e-05, 5.1292250456445516e-05, 5.051377489135613e-05, 5.001196713501025e-05, 4.9519083593087494e-05, 4.9229464522307575e-05, 4.90816231171811e-05, 4.910278905594476e-05, 4.933965724491461e-05]
plt.figure(figsize=(14,6))
to_plot=theall
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
theall_nosurf= [6.756611944141953e-05, 6.631176231976521e-05, 6.52521385056246e-05, 6.463319984145125e-05, 6.401456309539936e-05, 6.367245173095422e-05, 6.349874749829611e-05, 6.35647190067731e-05, 6.392622722665417e-05]
plt.figure(figsize=(14,6))
to_plot=theall_nosurf
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surfz_mt= [6.632315735577969e-06, 6.512181877508208e-06, 6.7268889726902575e-06, 6.593121423766957e-06, 6.460890357121316e-06, 6.3095788397899765e-06, 6.293070808815033e-06, 6.116436105222164e-06, 5.9416301562573995e-06]
plt.figure(figsize=(14,6))
to_plot=surfz_mt
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')

# %%
surfr_mt= [6.104515646144089e-06, 5.955247855464654e-06, 5.8704791244110855e-06, 5.703416607607585e-06, 5.6043998151824635e-06, 5.491426952945281e-06, 5.3674291388570085e-06, 5.317562301697312e-06, 5.2182644431344135e-06]
plt.figure(figsize=(14,6))
to_plot=surfr_mt
plt.scatter(depth,to_plot)
space=(np.max(to_plot)-np.min(to_plot))/10
plt.ylim(np.min(to_plot)-space,np.max(to_plot)+space)
plt.xlabel("depth(km)")
plt.ylabel("misfit(m)")
# Out:
# Text(0, 0.5, 'misfit(m)')
