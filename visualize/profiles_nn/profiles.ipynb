# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
import numpy.ma as ma
from scipy import interpolate
# %matplotlib inline

# %%
data=pd.read_csv("./ver_hresvs_vs_gmt",sep="\s+",names=["lon","lat","dep","val","x"])

# %%
data
# Out:
#            lon     lat    dep        val       x
# 0      145.000  30.000    0.0 -1000.0000     0.0
# 1      144.945  30.076    0.0 -1000.0000    10.0
# 2      144.890  30.153    0.0 -1000.0000    20.0
# 3      144.835  30.229    0.0 -1000.0000    30.0
# 4      144.780  30.305    0.0 -1000.0000    40.0
# 5      144.725  30.381    0.0 -1000.0000    50.0
# 6      144.669  30.458    0.0 -1000.0000    60.0
# 7      144.614  30.534    0.0 -1000.0000    70.0
# 8      144.558  30.610    0.0 -1000.0000    80.0
# 9      144.503  30.686    0.0 -1000.0000    90.0
# 10     144.447  30.762    0.0 -1000.0000   100.0
# 11     144.391  30.838    0.0 -1000.0000   110.0
# 12     144.335  30.915    0.0 -1000.0000   120.0
# 13     144.279  30.991    0.0 -1000.0000   130.0
# 14     144.223  31.067    0.0 -1000.0000   140.0
# 15     144.167  31.143    0.0 -1000.0000   150.0
# 16     144.111  31.219    0.0 -1000.0000   160.0
# 17     144.055  31.295    0.0 -1000.0000   170.0
# 18     143.998  31.371    0.0 -1000.0000   180.0
# 19     143.942  31.446    0.0 -1000.0000   190.0
# 20     143.885  31.522    0.0 -1000.0000   200.0
# 21     143.829  31.598    0.0 -1000.0000   210.0
# 22     143.772  31.674    0.0 -1000.0000   220.0
# 23     143.715  31.750    0.0 -1000.0000   230.0
# 24     143.658  31.826    0.0 -1000.0000   240.0
# 25     143.601  31.901    0.0 -1000.0000   250.0
# 26     143.544  31.977    0.0 -1000.0000   260.0
# 27     143.487  32.053    0.0 -1000.0000   270.0
# 28     143.429  32.129    0.0 -1000.0000   280.0
# 29     143.372  32.204    0.0 -1000.0000   290.0
# ...        ...     ...    ...        ...     ...
# 63970  114.448  55.228  795.0     6.2483  3700.0
# 63971  114.321  55.282  795.0     6.2485  3710.0
# 63972  114.194  55.335  795.0     6.2485  3720.0
# 63973  114.067  55.389  795.0     6.2485  3730.0
# 63974  113.939  55.442  795.0     6.2485  3740.0
# 63975  113.811  55.495  795.0     6.2486  3750.0
# 63976  113.683  55.548  795.0     6.2486  3760.0
# 63977  113.554  55.601  795.0     6.2485  3770.0
# 63978  113.425  55.653  795.0     6.2486  3780.0
# 63979  113.295  55.706  795.0     6.2487  3790.0
# 63980  113.165  55.758  795.0     6.2486  3800.0
# 63981  113.035  55.810  795.0     6.2486  3810.0
# 63982  112.905  55.863  795.0     6.2488  3820.0
# 63983  112.774  55.915  795.0     6.2487  3830.0
# 63984  112.643  55.966  795.0     6.2487  3840.0
# 63985  112.511  56.018  795.0     6.2489  3850.0
# 63986  112.379  56.070  795.0     6.2491  3860.0
# 63987  112.247  56.121  795.0     6.2491  3870.0
# 63988  112.114  56.172  795.0     6.2490  3880.0
# 63989  111.981  56.224  795.0     6.2493  3890.0
# 63990  111.848  56.275  795.0     6.2492  3900.0
# 63991  111.714  56.325  795.0     6.2494  3910.0
# 63992  111.580  56.376  795.0     6.2493  3920.0
# 63993  111.446  56.427  795.0     6.2495  3930.0
# 63994  111.311  56.477  795.0     6.2495  3940.0
# 63995  111.176  56.527  795.0     6.2495  3950.0
# 63996  111.041  56.578  795.0     6.2498  3960.0
# 63997  110.905  56.628  795.0     6.2496  3970.0
# 63998  110.769  56.677  795.0     6.2499  3980.0
# 63999  110.632  56.727  795.0     6.2499  3990.0
#
# [64000 rows x 5 columns]

# %%
x=data.x.values

# %%
y=data.dep.values

# %%
z=data.val.values

# %%
z[z==-1000.0]=np.nan

# %%
# define grid.
xi = np.linspace(np.min(x),np.max(x),1000)
yi = np.linspace(np.min(y),np.max(y),1000)

# %%
zi = griddata(x,y,z,xi,yi,method="nearest")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9371b5aa3650> in <module>
# ----> 1 zi = griddata(x,y,z,xi,yi,method="nearest")
#
# TypeError: griddata() got multiple values for argument 'method'

# %%
plt.figure(figsize=(18,9))
# CS = plt.contourf(xi,yi,zi,15,cmap=plt.cm.jet)
plt.scatter(x,y,c=z,s=3,cmap=plt.cm.jet)
plt.colorbar() # draw colorbar
plt.gca().invert_yaxis()
plt.xlim(0,4000)
plt.ylim(800,0)
plt.show()

# %%
plt.figure(figsize=(18,9))
CS = plt.contourf(xi,yi,zi,15,cmap=plt.cm.jet)
plt.colorbar() # draw colorbar
plt.gca().invert_yaxis()
plt.show()

# %%
ref=pd.read_csv("./STW105.txt",sep="\s+",names=["radius","density","vpv","vsv","kappa","miu","vph","vsh","eta"])

# %%
ref
# Out:
#         radius   density       vpv      vsv    kappa    miu       vph  \
# 0          0.0  13088.48  11262.20  3667.80   1327.6  104.0  11262.20
# 1       6824.0  13088.47  11262.20  3667.79   1327.6  104.0  11262.20
# 2      13648.0  13088.44  11262.18  3667.78   1327.6  104.0  11262.18
# 3      20472.0  13088.39  11262.14  3667.75   1327.6  104.0  11262.14
# 4      27296.0  13088.32  11262.09  3667.72   1327.6  104.0  11262.09
# 5      34120.0  13088.22  11262.02  3667.67   1327.6  104.0  11262.02
# 6      40944.0  13088.11  11261.94  3667.62   1327.6  104.0  11261.94
# 7      47768.0  13087.98  11261.85  3667.55   1327.6  104.0  11261.85
# 8      54592.0  13087.83  11261.74  3667.47   1327.6  104.0  11261.74
# 9      61416.0  13087.66  11261.61  3667.39   1327.6  104.0  11261.61
# 10     68240.0  13087.46  11261.47  3667.29   1327.6  104.0  11261.47
# 11     75064.0  13087.25  11261.32  3667.18   1327.6  104.0  11261.32
# 12     81888.0  13087.02  11261.15  3667.06   1327.6  104.0  11261.15
# 13     88712.0  13086.76  11260.97  3666.94   1327.6  104.0  11260.97
# 14     95536.0  13086.49  11260.77  3666.80   1327.6  104.0  11260.77
# 15    102360.0  13086.20  11260.56  3666.65   1327.6  104.0  11260.56
# 16    109184.0  13085.88  11260.34  3666.49   1327.6  104.0  11260.34
# 17    116007.0  13085.55  11260.09  3666.32   1327.6  104.0  11260.09
# 18    122831.0  13085.19  11259.84  3666.15   1327.6  104.0  11259.84
# 19    129655.0  13084.82  11259.57  3665.96   1327.6  104.0  11259.57
# 749  6371000.0   1020.00   1450.00     0.00  57822.5    0.0   1450.00
#
#          vsh  eta
# 0    3667.80  1.0
# 1    3667.79  1.0
# 2    3667.78  1.0
# 3    3667.75  1.0
# 4    3667.72  1.0
# 5    3667.67  1.0
# 6    3667.62  1.0
# 7    3667.55  1.0
# 8    3667.47  1.0
# 9    3667.39  1.0
# 10   3667.29  1.0
# 11   3667.18  1.0
# 12   3667.06  1.0
# 13   3666.94  1.0
# 14   3666.80  1.0
# 15   3666.65  1.0
# 16   3666.49  1.0
# 17   3666.32  1.0
# 18   3666.15  1.0
# 19   3665.96  1.0
# 20   3665.76  1.0
# 21   3665.55  1.0
# 22   3665.33  1.0
# 23   3665.10  1.0
# 24   3664.86  1.0
# 25   3664.61  1.0
# 26   3664.35  1.0
# 27   3664.08  1.0
# 28   3663.80  1.0
# 29   3663.51  1.0
# ..       ...  ...
# 720  3900.00  1.0
# 721  3900.00  1.0
# 722  3900.00  1.0
# 723  3900.00  1.0
# 724  3900.00  1.0
# 725  3900.00  1.0
# 726  3900.00  1.0
# 727  3900.00  1.0
# 728  3200.00  1.0
# 729  3200.00  1.0
# 730  3200.00  1.0
# 731  3200.00  1.0
# 732  3200.00  1.0
# 733  3200.00  1.0
# 734  3200.00  1.0
# 735  3200.00  1.0
# 736  3200.00  1.0
# 737  3200.00  1.0
# 738  3200.00  1.0
# 739     0.00  1.0
# 740     0.00  1.0
# 741     0.00  1.0
# 742     0.00  1.0
# 743     0.00  1.0
# 744     0.00  1.0
# 745     0.00  1.0
# 746     0.00  1.0
# 747     0.00  1.0
# 748     0.00  1.0
# 749     0.00  1.0
#
# [750 rows x 9 columns]

# %%
f = interpolate.interp1d((6371000.0-ref.radius)/1000, ref.vsh/1000.0)

# %%
z=data.val.values/f(y)
z[z<0]=0
z[np.isnan(z)]=0
z[z==-1000.0]=np.nan
# Out:
# /Users/ziyixi/anaconda3/envs/seismology/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/ziyixi/anaconda3/envs/seismology/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less

# %%
z=(z-1)

# %%
z[z==-1]=0

# %%
z
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.00120016,
#        -0.00115221, -0.00115221])

# %%
# zi = griddata(x,y,z,xi,yi,interp='linear')
# Out:
# /usr/local/anaconda3/envs/seismology/lib/python3.6/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: The griddata function was deprecated in Matplotlib 2.2 and will be removed in 3.1. Use scipy.interpolate.griddata instead.
#   """Entry point for launching an IPython kernel.

# %%
# plt.figure(figsize=(18,9))
# CS = plt.contourf(xi,yi,zi,15,cmap=plt.cm.seismic)
# plt.colorbar() # draw colorbar
# plt.gca().invert_yaxis()
# plt.show()
plt.figure(figsize=(18,9))
# CS = plt.contourf(xi,yi,zi,15,cmap=plt.cm.jet)
plt.scatter(x,y,c=z,s=3,cmap=plt.cm.seismic)
plt.colorbar() # draw colorbar
plt.gca().invert_yaxis()
plt.xlim(0,4000)
plt.ylim(800,0)
plt.show()
