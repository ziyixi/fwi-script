# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### event

# %%
event10s=pd.read_csv("../preprocessed_10s_to_120s.event.csv")

# %%
event10s=event10s.sort_values(by=["snr_z"],ascending=False).reset_index()

# %%
event10s
# Out:
#      index         gcmtid      snr_r      snr_t      snr_z    allsnr_r  \
# 0      287  201112271521A  26.241608  22.053789  30.865914  21518.1185
# 1      456  201707060803A  25.510217  18.198900  30.149406  28545.9326
# 2      251  201103241355A  26.648030  21.557273  29.229617  21931.3290
# 3       14  200803031349A  24.237565  25.108286  28.558611  18396.3117
# 4       38  200807131458A  23.704001  20.171805  27.308821  17920.2247
# 5       32  200806132343A  26.222823  19.433183  27.122071  21660.0522
# 6       25  200805092151A  24.775666  17.629600  26.532106   4335.7415
# 7      165  201003040018A  19.724363  14.576516  26.424501  17633.5808
# 8        1  200708020237A  20.486350  17.878793  26.133669  11841.1101
# 9       58  200812201029A  20.911618  18.508002  25.665145  12818.8217
# 10     218  201008140730A  17.897141  10.307151  25.066036   7874.7421
# 11     320  201211111054A  16.016306  15.763973  24.847557  15311.5882
# ...

# %%
event10s[event10s.gcmtid=="201003300102A"]
# Out:
#     index         gcmtid      snr_r      snr_t      snr_z    allsnr_r  \
# 76    179  201003300102A  11.815211  10.213616  19.107417  11118.1134
#
#      allsnr_t    allsnr_z  count
# 76  9611.0125  17980.0797    941

# %%
event10s[event10s.gcmtid=="200912240023A"]
# Out:
#      index         gcmtid    snr_r    snr_t      snr_z   allsnr_r   allsnr_t  \
# 219    136  200912240023A  7.65723  3.35225  10.454177  8078.3779  3536.6234
#
#        allsnr_z  count
# 219  11029.1569   1055

# %% [markdown]
# ### station

# %%
station10s=pd.read_csv("../preprocessed_10s_to_120s.station.csv")

# %%
station10s=station10s.sort_values(by=["allsnr_r"],ascending=False).reset_index()

# %%
station10s[100:]
# Out:
#       index   netsta      snr_r      snr_t      snr_z   allsnr_r   allsnr_t  \
# 100     279  FJ.PCNP   9.519707   7.245642  11.858896  4245.7893  3231.5564
# 101     865   LN.MQI   9.270509   7.346839  13.135178  4227.3520  3350.1587
# 102     182   BO.TKD   9.852933   6.921024  15.248115  4226.9082  2969.1195
# 103    1175   SX.JIC   9.295507   7.889173  12.208768  4220.1604  3581.6845
# 104    1068   SC.YGD   9.763500   8.171419  12.758250  4217.8318  3530.0530
# 105    1372   XJ.LHG  10.534558   8.615534  10.238168  4213.8231  3446.2135
# 106     264   CQ.YUB   9.398766   7.649512  11.176151  4201.2486  3419.3318
# 107     463    HA.XX   9.141186   7.342049  12.900961  4186.6634  3362.6583
# 108     355   GS.DBT  10.387487   8.790577  11.789330  4186.1572  3542.6025
# 109     137   BO.HRO   8.810249   4.140605  14.096022  4184.8684  1966.7873
# 110     219   BU.SHC  10.874801   7.515771  13.411520  4165.0486  2878.5403
# ...
